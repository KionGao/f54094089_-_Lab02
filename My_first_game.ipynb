# %%
import pygame #載入pygame模組


WIN_WIDTH = 1024
WIN_HEIGHT = 600
ENEMY_WIDTH = 50
ENEMY_HEIGHT = 50
BTN_WIDTH = 80
BTN_HEIGHT = 80
HP_WIDTH = 40
HP_HEIGHT = 40
FPS = 30


# 色盤 (RGB)
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# 初始化
pygame.init()
# create window surface
window = pygame.display.set_mode((WIN_WIDTH, WIN_HEIGHT))
# 設標題
pygame.display.set_caption("My first game")
# 時間
clock = pygame.time.Clock()
# 載入圖片 (background, enemy, buttons)
background = pygame.transform.scale(pygame.image.load("Map.png"), (WIN_WIDTH, WIN_HEIGHT))
enemy = pygame.transform.scale(pygame.image.load("enemy.png"), (ENEMY_WIDTH, ENEMY_HEIGHT))
hp_image = pygame.transform.scale(pygame.image.load("hp.png"), (HP_WIDTH, HP_HEIGHT))
hp_gray_image = pygame.transform.scale(pygame.image.load("hp_gray.png"), (HP_WIDTH, HP_HEIGHT))



#設定遊戲內資訊
class Game:
    def __init__(self):
        # window
        # ...(to be done)

        # hp
        self.hp = 7
        self.max_hp = 10
        pass

    def game_run(self):
        # 遊戲開始與結束迴圈
        time_start = time.time()
        run = True
        while run:
            clock.tick(FPS)
            # event loop
            for event in pygame.event.get():
                if event.type == pygame.QUIT: 
                    run = False   #結束
            # draw background
            window.blit(background, (0, 0))
            
            # draw enemy and health bar
            window.blit(enemy, (20, 270))
            pygame.draw.rect(window, RED, [20, 265, 50, 8]) #紅色,[(X,Y)]、[(寬,高)]         
            pygame.display.update() #跟進隨時更新的code內容

if __name__ == "__main__":
    covid_game = Game()
    covid_game.game_run()
    pygame.quit()
